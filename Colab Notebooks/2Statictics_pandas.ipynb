# %%
# pandas library - Panel data/Panel Data Analysis
# A python library used for working with data sets.
# Explanatory data analysis
# Has 2 main objectives
# Series - 1-D - (1 Row / 1 Column) - vectors in numpy
# Data Frame - 2-D - matrix in numpy

# %%
d = {'Name' : ['Mr V', 'Mr W', 'Mr X', 'Mr Y', 'Mr Z'],
     'Height' : [123, 121, 118, 110, 129],
     'Weight' : [76, 36, 64, 43, 71]}

import pandas as pd
df=pd.DataFrame(d)
print(df)
print("\nShape : ", df.shape) # Dimension of data
print("\nDescribe : \n", df.describe()) # Differnt metric attribute of the data
# Out:
#    Name  Height  Weight
# 0  Mr V     123      76
# 1  Mr W     121      36
# 2  Mr X     118      64
# 3  Mr Y     110      43
# 4  Mr Z     129      71
#
# Shape :  (5, 3)
#
# Describe :
#             Height     Weight
# count    5.000000   5.000000
# mean   120.200000  58.000000
# std      6.978539  17.592612
# min    110.000000  36.000000
# 25%    118.000000  43.000000
# 50%    121.000000  64.000000
# 75%    123.000000  71.000000
# max    129.000000  76.000000
